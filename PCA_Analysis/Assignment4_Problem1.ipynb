# %%
import pandas as pdd

# %%
data = pd.read_csv("/Users/nivethida/Downloads/accidentsFull.csv")
# Out:
#    HOUR_I_R  ALCHL_I  ALIGN_I  STRATUM_R  WRK_ZONE  WKDY_I_R  INT_HWY  \
# 0         0        2        2          1         0         1        0
# 1         1        2        1          0         0         1        1
# 2         1        2        1          0         0         1        0
# 3         1        2        1          1         0         0        0
# 4         1        1        1          0         0         1        0
#
#    LGTCON_I_R  MANCOL_I_R  PED_ACC_R  ...  SUR_COND  TRAF_CON_R  TRAF_WAY  \
# 0           3           0          0  ...         4           0         3
# 1           3           2          0  ...         4           0         3
# 2           3           2          0  ...         4           1         2
# 3           3           2          0  ...         4           1         2
# 4           3           2          0  ...         4           0         2
#
#    VEH_INVL  WEATHER_R  INJURY_CRASH  NO_INJ_I  PRPTYDMG_CRASH  FATALITIES  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42183 entries, 0 to 42182
# Data columns (total 24 columns):
# HOUR_I_R          42183 non-null int64
# ALCHL_I           42183 non-null int64
# ALIGN_I           42183 non-null int64
# STRATUM_R         42183 non-null int64
# WRK_ZONE          42183 non-null int64
# WKDY_I_R          42183 non-null int64
# INT_HWY           42183 non-null int64
# LGTCON_I_R        42183 non-null int64
# MANCOL_I_R        42183 non-null int64
# PED_ACC_R         42183 non-null int64
# RELJCT_I_R        42183 non-null int64
# REL_RWY_R         42183 non-null int64
# PROFIL_I_R        42183 non-null int64
# SPD_LIM           42183 non-null int64
# SUR_COND          42183 non-null int64
# TRAF_CON_R        42183 non-null int64
# TRAF_WAY          42183 non-null int64
# VEH_INVL          42183 non-null int64
# WEATHER_R         42183 non-null int64
# INJURY_CRASH      42183 non-null int64
# NO_INJ_I          42183 non-null int64
# ...

# %%
for x in data.columns:
    print(data.groupby([x]).size())
# Out:
# HOUR_I_R
# 0    24072
# 1    18111
# dtype: int64
# ALCHL_I
# 1     3677
# 2    38506
# dtype: int64
# ALIGN_I
# 1    36634
# 2     5549
# dtype: int64
# STRATUM_R
# 0    21445
# 1    20738
# dtype: int64
# WRK_ZONE
# 0    41229
# 1      954
# dtype: int64
# WKDY_I_R
# 0     9634
# 1    32549
# dtype: int64
# INT_HWY
# 0    36066
# 1     6089
# 9       28
# dtype: int64
# LGTCON_I_R
# 1    29294
# 2     5002
# 3     7887
# dtype: int64
# MANCOL_I_R
# 0    13519
# 1      926
# 2    27738
# dtype: int64
# PED_ACC_R
# 0    40474
# 1     1709
# dtype: int64
# RELJCT_I_R
# 0    18648
# 1    23535
# dtype: int64
# REL_RWY_R
# 0     9848
# 1    32335
# dtype: int64
# PROFIL_I_R
# 0    31923
# 1    10260
# dtype: int64
# SPD_LIM
# 5        6
# 10      22
# 15     183
# 20     251
# 25    4205
# 30    3715
# 35    8541
# 40    4304
# 45    6587
# 50    1665
# 55    6594
# 60    1658
# 65    2715
# 70    1454
# 75     283
# dtype: int64
# SUR_COND
# 1    33605
# 2     6918
# 3      565
# ...
